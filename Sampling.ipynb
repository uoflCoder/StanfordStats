# %%
import pandas as pd
population_data = pd.read_csv('PopulationData.csv')

# %%
#Get rid of first column it is useless
population_data = population_data.iloc[:, 1:len(population_data.axes[1])]

# %%
population_data.head()
# Out:
#     Course Handed     Sex  Verbal    Age
# 0   Social   left    male   470.0  18.83
# 1   Social  right  female   650.0  18.67
# 2   Social  right    male   580.0  20.08
# 3   Social  right  female   660.0  18.50
# 4   Social  right  female   790.0  24.25

# %%
population_data.sample?

# %%
#Get a random sample of 192 students
population_sample = population_data.sample(192, random_state=42)

# %%
population_sample
# Out:
#         Course Handed     Sex  Verbal    Age
# 743     Social  right  female   590.0  45.33
# 1010  Business  right  female   510.0  18.42
# 1123  Business  right  female   550.0  21.17
# 140   Business   left    male   590.0  19.17
# 554     Social  right    male   580.0  23.08
# 327     Social  right    male     NaN  22.25
# 813     Social  right    male   510.0  25.00
# 798     Social  right  female   450.0  19.42
# 1121    Social  right  female   430.0  19.50
# 828     Social  right  female   520.0  26.17
# 494     Social  right    male   630.0  20.58
# 759     Social  right    male   670.0  20.92
# 677   Business  right  female   500.0  18.92
# 1053  Business   left    male   760.0  23.00
# 70      Social  right    male   540.0  20.25
# 1047    Social  right  female   480.0  20.50
# 192     Social  right    male   660.0  18.58
# 526     Social  right  female   700.0  20.17
# 660    Natural  right    male   590.0  20.50
# 334     Social  right    male   560.0  19.33
# ...
