# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
 

import pandas as pd
population_data = pd.read_csv('PopulationData.csv')

# %%
#Get rid of first column it is useless
population_data = population_data.iloc[:, 1:len(population_data.axes[1])]

# %%
population_data.head()
# Out:
#     Course Handed     Sex  Verbal    Age
# 0   Social   left    male   470.0  18.83
# 1   Social  right  female   650.0  18.67
# 2   Social  right    male   580.0  20.08
# 3   Social  right  female   660.0  18.50
# 4   Social  right  female   790.0  24.25

# %%
#Get a random sample of 192 students
population_sample = population_data.sample(192, random_state=42)

# %%
left_population = population_sample["Handed"].loc[population_sample['Handed'] == 'left']
left_population = left_population.count()

right_population = population_sample["Handed"].loc[population_sample['Handed'] == 'right']
right_population = right_population.count()

# %%
objects = ('left', 'right')
y_pos = np.arange(len(objects))
distribution = [left_population,right_population]
 
plt.bar(y_pos, distribution, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Number of Handed')
plt.title('Handed Distribution')
plt.ylim(0,1000)
plt.show()

# %%
left_population = population_data["Handed"].loc[population_data['Handed'] == 'left']
left_population = left_population.count()

right_population = population_data["Handed"].loc[population_data['Handed'] == 'right']
right_population = right_population.count()

objects = ('left', 'right')
y_pos = np.arange(len(objects))
distribution = [left_population,right_population]
 
plt.bar(y_pos, distribution, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Number of Handed')
plt.title('Handed Distribution')
plt.ylim(0,1000)
plt.show()

# %%
#Compare the distribution between train_set and test_set
print(population_data.Handed.value_counts() / len(population_data))
print("\n")
print(population_sample.Handed.value_counts() / len(population_sample))
# Out:
# right    0.867139
# left     0.132861
# Name: Handed, dtype: float64
#
#
# right    0.848958
# left     0.151042
# Name: Handed, dtype: float64

# %%
population_sample.Handed.summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-9fe05beecfc6> in <module>()
# ----> 1 population_sample.Handed.summary()
#
# C:\Users\STCO224\Documents\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'summary'

# %%
pie_chart = population_data.Sex.value_counts()

plt.pie(pie_chart, labels = pie_chart.index.tolist(), autopct = '%1.02f%%')
plt.title('Population Sex Distribution')
plt.show()

# %%
pie_chart = population_sample.Sex.value_counts()

plt.pie(pie_chart, labels = pie_chart.index.tolist(), autopct = '%1.02f%%')
plt.title('Sample population Sex Distribution')
plt.show()

# %%
population_data.Verbal.describe()
# Out:
# count    998.000000
# mean     588.780561
# std       76.081470
# min      300.000000
# 25%      540.000000
# 50%      590.000000
# 75%      640.000000
# max      800.000000
# Name: Verbal, dtype: float64

# %%
population_sample.Verbal.describe()
# Out:
# count    171.000000
# mean     590.087719
# std       69.183205
# min      400.000000
# 25%      545.000000
# 50%      590.000000
# 75%      640.000000
# max      790.000000
# Name: Verbal, dtype: float64

# %%
population_data.Age.describe()
# Out:
# count    1123.000000
# mean       20.374898
# std         3.188835
# min        17.670000
# 25%        19.080000
# 50%        19.670000
# 75%        20.670000
# max        74.170000
# Name: Age, dtype: float64

# %%
population_sample.Age.describe()
# Out:
# count    192.000000
# mean      20.156406
# std        2.551453
# min       18.000000
# 25%       19.080000
# 50%       19.580000
# 75%       20.250000
# max       45.330000
# Name: Age, dtype: float64
